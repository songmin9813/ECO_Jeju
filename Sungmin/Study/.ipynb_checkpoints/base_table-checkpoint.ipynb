# %%
import pandas as pd
import numpy as np
import datetime
import pickle

# %%
food=pd.read_csv("C:/Users/mitha/OneDrive/바탕 화면/datas/food_waste.csv",encoding='CP949',low_memory=False)

# %%
food.head()
# Out:
#     base_date city    emd_cd emd_nm em_area_cd  em_cnt   em_g  pay_amt
# 0  2018-01-01  제주시  50110670    외도동     W6X062       2  15500      464
# 1  2018-01-01  제주시  50110630    아라동     W6XA97      25  59800     1787
# 2  2018-01-01  제주시  50110630    아라동     W6XA96       8  25350      758
# 3  2018-01-01  제주시  50110630    아라동     W6XA95      12  30000      898
# 4  2018-01-01  제주시  50110630    아라동     W6XA94      14  44050     1317

# %%
food['base_date']
# Out:
# 0          2018-01-01
# 1          2018-01-01
# 2          2018-01-01
# 3          2018-01-01
# 4          2018-01-01
#               ...
# 2211440    2021-06-30
# 2211441    2021-06-30
# 2211442    2021-06-30
# 2211443    2021-06-30
# 2211444    2021-06-30
# Name: base_date, Length: 2211445, dtype: object

# %%
temp=datetime.datetime(2018,1,1)
tomorrow=temp+datetime.timedelta(days=1)
print(tomorrow)
# Out:
# 2018-01-02 00:00:00

# %%
import datetime
 
now = datetime.datetime.now()
print(type(now))      # 2018-07-28 12:40:00.320686
 
tomorrow = now + datetime.timedelta(days=1)
print(tomorrow) # 2018-07-29 12:40:00.320686
# Out:
# <class 'datetime.datetime'>
# 2021-08-21 11:38:40.123981

# %%
currentdate = temp.strftime('%Y-%m-%d')
print(currentdate)  # 2018-07-28 12:11:32
# Out:
# 2018-01-01

# %%
temp1=datetime.datetime(2018,1,2)
temp2=datetime.datetime(2018,1,3)
if temp1==temp2:
    print("hi")
# Out:
# hi

# %% [markdown]
# - 실험 끝

# %%
end_point=datetime.datetime(2021,7,1)#중단점 설정
start_point=datetime.datetime(2018,1,1)#시작점 설정

# %%
while end_point!=start_point:
    currentdate=start_point.strftime('%Y-%m-%d')
    print(currentdate)
    
    start_point+=datetime.timedelta(days=1)
# Out:
# 2018-01-01
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-06
# 2018-01-07
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-13
# 2018-01-14
# 2018-01-15
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-20
# 2018-01-21
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-27
# 2018-01-28
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-03
# 2018-02-04
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-10
# 2018-02-11
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-17
# 2018-02-18
# 2018-02-19
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-24
# 2018-02-25
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-03
# 2018-03-04
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-10
# 2018-03-11
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-17
# ...

# %%
class_group=food.groupby('city')

# %%
class_group.sum()
# Out:
#         em_cnt         em_g     pay_amt
# city
# 서귀포시  10096837  30094168730   905694550
# 알수없음     25251    151264969     4531655
# 제주시   36869285  75921424369  2266894400

# %%
waste_group=food.groupby(['base_date','emd_nm'])

# %%
waste_group.sum()
# Out:
#                    em_cnt     em_g  pay_amt
# base_date  emd_nm
# 2018-01-01 건입동        668  1708250    51079
#            남원읍        304  1239600    37110
#            노형동       3903  9357900   278317
#            대륜동        650  1717700    50076
#            대정읍        309  1264950    37872
# ...                   ...      ...      ...
# 2021-06-30 표선면        370  1377450    41235
#            한경면        269   973850    29152
#            한림읍        870  3298100    98740
#            화북동       2255  3749600   111933
#            효돈동        313  1011050    30253
#
# [50522 rows x 3 columns]

# %%
card=pd.read_csv("C:/Users/mitha/OneDrive/바탕 화면/datas/card_spending.csv",encoding='CP949',low_memory=False)
card.head()
# Out:
#     base_date city    emd_cd emd_nm mct_cat_cd mct_cat_nm  use_cnt    use_amt
# 0  2018-01-06  제주시  50110650     연동     C00100         한식     3643  127777300
# 1  2018-01-09  제주시  50110650     연동     C00500      패스트푸드      432    6711675
# 2  2018-01-15  제주시  50110650     연동     C01200      농축수산물      236   16089579
# 3  2018-01-15  제주시  50110650     연동     A00200    마트/슈퍼마켓     4031  121979867
# 4  2018-01-20  제주시  50110650     연동     C01000         식품      633   30410674

# %%
card_group=card.groupby(['base_date','emd_nm'])
card_group.sum()
# Out:
#                    use_cnt    use_amt
# base_date  emd_nm
# 2018-01-01 건입동        1806   61606900
#            구좌읍        1180   43303254
#            남원읍        1581   69402997
#            노형동       12507  403571632
#            대륜동        2032   72541912
# ...                    ...        ...
# 2021-06-30 표선면        1336   90632868
#            한경면        1286   45263612
#            한림읍        3044  130156819
#            화북동        5644  191816310
#            효돈동         714   31043903
#
# [56188 rows x 2 columns]

# %%
korean=pd.read_csv("C:/Users/mitha/OneDrive/바탕 화면/datas/korean.csv",encoding='CP949',low_memory=False)
korean.head()
# Out:
#     base_date  time city    emd_cd emd_nm sex  age  resd_pop_cnt  \
# 0  2018-01-01     1  제주시  50110250    한림읍  여성    0      638.5509
# 1  2018-01-01     1  제주시  50110250    한림읍  여성    0        0.0000
# 2  2018-01-01     1  제주시  50110250    한림읍  여성   10      668.4577
# 3  2018-01-01     1  제주시  50110250    한림읍  여성   10        0.0000
# 4  2018-01-01     1  제주시  50110250    한림읍  여성   20      609.7710
#
#    work_pop_cnt  visit_pop_cnt resd
# 0       15.5400       151.5149   제주
# 1        3.7249       171.3458   그외
# 2       17.0308       166.0500   제주
# 3        4.2577       195.8539   그외
# 4        5.9490       148.7246   제주

# %%
korean_count=korean.drop(['city','emd_cd','resd_pop_cnt','work_pop_cnt','visit_pop_cnt'],axis=1)

# %%
korean_count_temp=pd.get_dummies(korean_count,columns=['sex','age','resd'])

# %%
korean_count_group=korean_count_temp.groupby(['base_date','emd_nm','time'])

# %%
korean_count_group.sum()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-73-8f024bdf2e2a> in <module>
# ----> 1 korean_count_group.sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in sum(self, numeric_only, min_count)
#    1648         # _agg_general() returns. GH #31422
#    1649         with com.temp_setattr(self, "observed", True):
# -> 1650             result = self._agg_general(
#    1651                 numeric_only=numeric_only,
#    1652                 min_count=min_count,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#    1022             result = None
#    1023             try:
# -> 1024                 result = self._cython_agg_general(
#    1025                     how=alias,
#    1026                     alt=npfunc,
#
# ...

# %%
korean_group=korean.groupby(['base_date','emd_nm','time'])
korean_group.sum()
# Out:
#                             emd_cd   age  resd_pop_cnt  work_pop_cnt  \
# base_date  emd_nm time
# 2018-01-01 건입동    1     1803981240  1440     8234.3087      506.5472
#                   2     1803981240  1440     8395.8304      501.6065
#                   3     1803981240  1440     8436.3172      477.0906
#                   4     1803981240  1440     8449.7851      451.9721
#                   5     1703760060  1290     8438.1201      460.2766
# ...                            ...   ...           ...           ...
# 2021-06-30 효돈동    20    1804699800  1440     3403.1940      176.5715
#                   21    1804699800  1440     3598.4514      155.6464
#                   22    1804699800  1440     3793.2173      136.4883
#                   23    1804699800  1440     3998.1158      121.6452
#                   24    1804699800  1440     4939.2441       75.4621
#
#                         visit_pop_cnt
# base_date  emd_nm time
# 2018-01-01 건입동    1         5123.2413
# ...

# %%
korean_assemble1=korean_group.sum().drop(['emd_cd','age'],axis=1)

# %%
f = open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/korean_assemble1.pkl", 'wb')
pickle.dump(korean_assemble1,f)
f.close()

# %%
f = open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/card_group.pkl", 'wb')
pickle.dump(card_group.sum(),f)
f.close()

# %%
fread=open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/korean_assemble1.pkl", 'rb')
korean_assemble1=pickle.load(fread)
fread.close()

# %%
fread=open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/korean_count_group.pkl", 'rb')
korean_count_group=pickle.load(fread)
fread.close()

# %%
korean_assemble2=korean_count_group.sum()

# %%
f = open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/korean_assemble2.pkl", 'wb')
pickle.dump(korean_assemble1,f)
f.close()

# %%
korean_assemble1
# Out:
#                         resd_pop_cnt  work_pop_cnt  visit_pop_cnt
# base_date  emd_nm time
# 2018-01-01 건입동    1        8234.3087      506.5472      5123.2413
#                   2        8395.8304      501.6065      5236.8215
#                   3        8436.3172      477.0906      5190.2790
#                   4        8449.7851      451.9721      5257.0690
#                   5        8438.1201      460.2766      5436.7787
# ...                              ...           ...            ...
# 2021-06-30 효돈동    20       3403.1940      176.5715      1857.2576
#                   21       3598.4514      155.6464      1776.4128
#                   22       3793.2173      136.4883      1802.0158
#                   23       3998.1158      121.6452      1692.6367
#                   24       4939.2441       75.4621       926.5442
#
# [1317864 rows x 3 columns]

# %%
korean_assemble2
# Out:
#                         sex_남성  sex_여성  age_0  age_10  age_20  age_30  age_40  \
# base_date  emd_nm time
# 2018-01-01 건입동    1         18      18      4       4       4       4       4
#                   2         18      18      4       4       4       4       4
#                   3         18      18      4       4       4       4       4
#                   4         18      18      4       4       4       4       4
#                   5         16      18      4       4       4       4       4
# ...                        ...     ...    ...     ...     ...     ...     ...
# 2021-06-30 효돈동    20        18      18      4       4       4       4       4
#                   21        18      18      4       4       4       4       4
#                   22        18      18      4       4       4       4       4
#                   23        18      18      4       4       4       4       4
#                   24        18      18      4       4       4       4       4
#
# ...

# %%
korean = pd.concat([korean_assemble1,korean_assemble2],axis=1)

# %%
korean
# Out:
#                         resd_pop_cnt  work_pop_cnt  visit_pop_cnt  sex_남성  \
# base_date  emd_nm time
# 2018-01-01 건입동    1        8234.3087      506.5472      5123.2413      18
#                   2        8395.8304      501.6065      5236.8215      18
#                   3        8436.3172      477.0906      5190.2790      18
#                   4        8449.7851      451.9721      5257.0690      18
#                   5        8438.1201      460.2766      5436.7787      16
# ...                              ...           ...            ...     ...
# 2021-06-30 효돈동    20       3403.1940      176.5715      1857.2576      18
#                   21       3598.4514      155.6464      1776.4128      18
#                   22       3793.2173      136.4883      1802.0158      18
#                   23       3998.1158      121.6452      1692.6367      18
#                   24       4939.2441       75.4621       926.5442      18
#
# ...

# %%
f = open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/korean_group.pkl", 'wb')
pickle.dump(korean,f)
f.close()

# %%
long_frgn=pd.read_csv("C:/Users/mitha/OneDrive/바탕 화면/datas/long_term_frgn.csv",encoding='CP949',low_memory=False)
long_frgn.head()
# Out:
#     base_date  time nationality city    emd_cd emd_nm  resd_pop_cnt  \
# 0  2018-01-01     1         CAN  제주시  50110250    한림읍        6.3381
# 1  2018-01-01     1         CHN  제주시  50110250    한림읍      442.1091
# 2  2018-01-01     1         CHN  제주시  50110250    한림읍        0.0000
# 3  2018-01-01     1         DEU  제주시  50110250    한림읍        0.0000
# 4  2018-01-01     1         ETC  제주시  50110250    한림읍       15.9184
#
#    work_pop_cnt  visit_pop_cnt resd
# 0        0.0000         4.5802   제주
# 1        0.0000         5.7051   제주
# 2        7.8695        51.3461   그외
# 3        0.0000         8.2099   그외
# 4        0.0000         2.8758   제주

# %%
long_group=long_frgn.groupby(['base_date','emd_nm','time'])
long_assemble1=long_group.sum().drop(['emd_cd'],axis=1)

# %%
long_count=long_frgn.drop(['emd_cd','resd_pop_cnt','work_pop_cnt','visit_pop_cnt'],axis=1)
long_count_temp=pd.get_dummies(long_count,columns=['nationality','resd','city'])
long_count_group=long_count_temp.groupby(['base_date','emd_nm','time'])
long_count_group.sum()
# Out:
#                         nationality_AUS  nationality_BGD  nationality_CAN  \
# base_date  emd_nm time
# 2018-01-01 건입동    1                   0                0                0
#                   2                   0                0                0
#                   3                   0                0                0
#                   4                   0                0                0
#                   5                   0                0                0
# ...                                 ...              ...              ...
# 2021-06-30 효돈동    20                  0                0                1
#                   21                  0                0                0
#                   22                  0                0                0
#                   23                  0                0                0
#                   24                  0                0                0
#
# ...

# %%
f = open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/long_count_group.pkl", 'wb')
pickle.dump(long_count_group,f)
f.close()

# %%
f = open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/long_assemble1.pkl", 'wb')
pickle.dump(long_assemble1,f)
f.close()

# %%
fread=open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/long_assemble1.pkl", 'rb')
long_assemble1=pickle.load(fread)
fread.close()

# %%
long_assemble2=long_count_group.sum()

# %%
f = open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/long_assemble2.pkl", 'wb')
pickle.dump(long_assemble2,f)
f.close()

# %%
long_group=pd.concat([long_assemble1,long_assemble2],axis=1)
long_group
# Out:
#                         resd_pop_cnt  work_pop_cnt  visit_pop_cnt  \
# base_date  emd_nm time
# 2018-01-01 건입동    1         194.4027       30.5056       156.1608
#                   2         196.6941       22.6345       148.8606
#                   3         183.3233       22.6345       151.8221
#                   4         188.7795       13.3501       147.8880
#                   5         188.8245        7.8735       147.3685
# ...                              ...           ...            ...
# 2021-06-30 효돈동    20         47.1162        5.2404        47.4853
#                   21         41.8758        5.2404        30.2029
#                   22         40.3908        5.2404        25.3556
#                   23         40.3908        0.0000        29.8181
#                   24         52.6508        0.0000        20.0184
#
#                         nationality_AUS  nationality_BGD  nationality_CAN  \
# base_date  emd_nm time
# ...

# %%
f = open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/long_group.pkl", 'wb')
pickle.dump(long_group,f)
f.close()

# %%
short_frgn=pd.read_csv("C:/Users/mitha/OneDrive/바탕 화면/datas/short_term_frgn.csv",encoding='CP949',low_memory=False)

# %%
short_group=short_frgn.drop(['emd_cd'],axis=1).groupby(['base_date','emd_nm','time'])
short_group.sum()
# Out:
#                         visit_pop_cnt
# base_date  emd_nm time
# 2018-01-01 건입동    1          215.3073
#                   2          216.5271
#                   3          236.7032
#                   4          234.7976
#                   5          234.7976
# ...                               ...
# 2021-06-30 화북동    21           1.8424
#                   22           1.8424
#                   23           1.8424
#                   24           1.8424
#            효돈동    24           0.9212
#
# [1247944 rows x 1 columns]

# %%
short_count=short_frgn.drop(['emd_cd','visit_pop_cnt'],axis=1)
short_count_temp=pd.get_dummies(short_count,columns=['nationality','city'])
short_count_group=short_count_temp.groupby(['base_date','emd_nm','time'])
short_count_group.sum()
# Out:
#                         nationality_CHN  nationality_ETC  nationality_HKG  \
# base_date  emd_nm time
# 2018-01-01 건입동    1                   1                1                1
#                   2                   1                1                1
#                   3                   1                1                1
#                   4                   1                1                1
#                   5                   1                1                1
# ...                                 ...              ...              ...
# 2021-06-30 화북동    21                  0                0                0
#                   22                  0                0                0
#                   23                  0                0                0
#                   24                  0                0                0
#            효돈동    24                  0                0                0
#
# ...

# %%
short_group=pd.concat([short_count_group.sum(),short_group.sum()],axis=1)

# %%
short_group
# Out:
#                         nationality_CHN  nationality_ETC  nationality_HKG  \
# base_date  emd_nm time
# 2018-01-01 건입동    1                   1                1                1
#                   2                   1                1                1
#                   3                   1                1                1
#                   4                   1                1                1
#                   5                   1                1                1
# ...                                 ...              ...              ...
# 2021-06-30 화북동    21                  0                0                0
#                   22                  0                0                0
#                   23                  0                0                0
#                   24                  0                0                0
#            효돈동    24                  0                0                0
#
# ...

# %%
f = open("C:/Users/mitha/OneDrive/바탕 화면/new_datas/short_group.pkl", 'wb')
pickle.dump(short_group,f)
f.close()

# %%
short_frgn=pd.read_csv("C:/Users/mitha/OneDrive/바탕 화면/datas/resident_pop.csv",encoding='CP949',low_memory=False)
resi_group=resi_frgn.drop(['emd_cd'],axis=1).groupby(['base_year','base_month','emd_nm'])

resi_count=resi_frgn.drop(['emd_cd','visit_pop_cnt'],axis=1)
resi_count_temp=pd.get_dummies(resi_count,columns=['nationality','city'])
resi_count_group=resi_count_temp.groupby(['base_date','emd_nm','time'])

resi_group=pd.concat([resi_count_group.sum(),resi_group.sum()],axis=1)
resi_group
